# %%
import polars as pl

# %%
import matplotlib as m
m.__version__
# Out:
# '3.9.2'

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.set()

# %%
tips = sns.load_dataset('tips').dropna()
tips.head(40)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.kdeplot(tips.tip,shade = True, color = 'violet',bw = 0.2);
# Out:
# C:\Users\lr7273ow\AppData\Local\Temp\ipykernel_10728\1611645577.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(tips.tip,shade = True, color = 'violet',bw = 0.2);
# C:\Users\lr7273ow\AppData\Local\Temp\ipykernel_10728\1611645577.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips.tip,shade = True, color = 'violet',bw = 0.2);

# %%
 sns.kdeplot(tips.tip,cumulative = True)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#Bivariate version 
sns.kdeplot(x=tips.tip,y= tips.total_bill,color = 'blue', shade = True);
# Out:
# C:\Users\lr7273ow\AppData\Local\Temp\ipykernel_10728\2064433547.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=tips.tip,y= tips.total_bill,color = 'blue', shade = True);
